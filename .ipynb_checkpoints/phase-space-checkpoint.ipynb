# %% [markdown]
# # Phase Space Analysis
# January 27, 2020

# %% [markdown]
# ### Methods and Parameters

# %%
#libraries
import math
# Base equations for Taylor-Couette (Concentric cylinder) Flow

#CONSTANTS
visc_37 = 0.0035 # Viscosity, Pa*s 
temp_factor = 1.27 # Conversion factor from 37 to 22

# Conversion from rad/s to RPM and back
def RPM(rad):
    return rad*30/math.pi
def rad(RPM):
    return RPM*math.pi/30

# Calculate shear rate in concentric cylinder flow (laminar, idealized)
# r is optional and represents distance from inner to outer (0 to 1)
def shear_Rate(r_i, r_0, w, r=1):
    r = r_i + r*(r_0-r_i)
    out = 2*(r_0**2 * r_i**2 * rad(w))   /   ((r_0**2 - r_i**2) * r**2)
    return out

# Same as above but for calculating RPM
def ang_vel(r_i, r_0, w, r=1):
    r = r_i + r*(r_0-r_i)
    out = rad(w)*((r_0**2 - r_i**2) * r**2) / 2*(r_0**2 * r_i**2 )  
    return out

# Calculate stability (Taylor Number) of flow
def Ta(r_i, r_0, w):
    return rad(w)**2*r_i*(r_0-r_i)**3/((4.566e-6)**2)

# Concentric cylinder wetted surface area approximation (slight overestimate)
def surf_Area(r_i, r_0):
    H = 0.015 # 1.5 cm
    return 0.01 * (2*H*(r_i+r_0)+(r_0**2+r_i**2) / (H*(r_0**2 - r_i**2)))

# Surface area of a tube for comparison
def surf_Tube(rad):
    return 0.01*2/rad

# %% [markdown]
# ## Goal
# Illustrate the capabilities of this Flow for modelling shear-biomaterial interactions.
#
# ### How
# Want to produce a phase portrait of:
# - x (shear rate) vs y (surface to volume ratio)
# - for a range of radius ratios
# - also show the values which lie within the laminar flow regime

# %% [markdown]
# Generate
# 1. A series of outer radii.
# 2. A series of ratios between 0 and 1
# 3. Shear rates that will be tested

# %%
import numpy as np
r_0 = 0.0081
r_outers = [r_0]
#r_outers = [r_0/2,r_0,r_0*2,r_0*4]
ratios = np.linspace(0.8,0.95,7)
velos = np.arange(200,1600,200)

# %%
velos
# Out:
# array([ 200,  400,  600,  800, 1000, 1200, 1400])

# %% [markdown]
# Simple case:
# outer radius = 0.002

# %%
r_outer = r_outers[0]
x = []
y = []
z = []
for i in range(0,len(velos)):
    tmp = []
    tmp2 = []
    tmp3 = []
    for j in range(0,len(ratios)):
        tmp.append(shear_Rate(r_outer*ratios[j],r_outer,velos[i]))
        tmp2.append(surf_Area(r_outer*ratios[j],r_outer))
        tmp3.append(Ta(r_outer*ratios[j],r_outer,velos[i]))
    x.append(tmp)
    y.append(tmp2)
    z.append(tmp3)

# %% [markdown]
# TRYING LIST COMPREHENSION
# Each curve plots 5 ratios
# Each family of curves (right shift in shear) is velocities

# %%
listcomp = [[shear_Rate(i*j,i,velos), surf_Area(i*ratios,i), Ta(i*j,i,velos)] 
             for i in r_outers for j in ratios]

# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(12,7))
plt.subplot(121)
plt.plot(ratios,listcomp[0][1],'.-')
#plt.hlines(1700,xmin=0,xmax=3000,linestyle='dashed',label='Critical Ta')
plt.xlabel('Radius Ratio')
plt.ylabel('Surface Area, cm^2/ml')
#plt.xscale('log')
#plt.yscale('log')
plt.suptitle('Design Space')

plt.subplot(122)
for i in range(0,len(listcomp)):
    plt.plot(listcomp[i][0],listcomp[i][2],'.-',label="{:.2f}".format(ratios[i]))
plt.hlines(1700,xmin=0,xmax=10000,linestyle='dashed',label='Critical Ta')
plt.show
plt.xlabel('Shear Rate')
plt.ylabel('Taylor Number')
plt.xscale('log')
plt.yscale('log')
plt.suptitle('Design Space: r_0 = 0.0081 m')
plt.legend()
plt.show()

# %%
surf_Tube(0.00235)
# Out:
# 8.51063829787234

# %%
surf_Area(0.0055,0.00635)
# Out:
# 4.670972364464713

# %%
r_outer = r_outers[0]
v = []
w = []
for i in range(0,len(velos)):
    tmp = []
    tmp2 = []
    for j in range(0,len(ratios)):
        tmp.append(shear_Rate(r_outer*ratios[j],r_outer,velos[i]))
        tmp2.append(surf_Area(r_outer*ratios[j],r_outer))
    v.append(tmp)
    w.append(tmp2)

# %%
import matplotlib.pyplot as plt

for i in range(0,len(x)):
    plt.plot(x[i],z[i],'.-')
    plt.plot(v[i],w[i],'.-')
plt.hlines(1700,xmin=0,xmax=10000,linestyle='dashed')
plt.show
plt.xlabel('Shear Rate')
plt.ylabel('Surf Area')
plt.xscale('log')
plt.yscale('log')
plt.suptitle('Design Space')
# Out:
# Text(0.5, 0.98, 'Design Space')

# %%
import matplotlib.pyplot as plt

for i in range(0,len(x)):
    plt.plot(x[i],y[i],'.-')
    plt.plot(v[i],w[i],'.-')
plt.show
plt.xlabel('Shear Rate')
plt.ylabel('Surf Area')
plt.xscale('log')
plt.yscale('log')
plt.suptitle('Design Space')
# Out:
# Text(0.5, 0.98, 'Design Space')

# %% [markdown]
# Doesn't work that well. What about "Operating Space":
# - instead of showing how each line as a radius and range of ratios can show:
#     - given physical arrangement and range of velocities

# %%
xx,yy,zz = np.meshgrid(r_outers, ratios, s_rates)

# %%
grid = np.vstack([xx.ravel(), yy.ravel(), zz.ravel()])

# %%
# Out:
# array([[2.00000000e-03, 2.00000000e-03, 2.00000000e-03, 2.00000000e-03,
#         2.00000000e-03, 2.00000000e-03, 2.00000000e-03, 2.00000000e-03,
#         2.00000000e-03, 2.00000000e-03, 2.00000000e-03, 2.00000000e-03,
#         2.00000000e-03, 2.00000000e-03, 2.00000000e-03, 2.00000000e-03,
#         2.00000000e-03, 2.00000000e-03, 2.00000000e-03, 2.00000000e-03],
#        [1.11288889e+00, 1.11288889e+00, 1.11288889e+00, 1.11288889e+00,
#         1.11288889e+00, 1.11288889e+00, 1.11288889e+00, 1.11288889e+00,
#         1.11288889e+00, 1.11288889e+00, 1.11288889e+00, 1.11288889e+00,
#         1.11288889e+00, 1.11288889e+00, 1.11288889e+00, 1.11288889e+00,
#         1.11288889e+00, 1.11288889e+00, 1.11288889e+00, 1.11288889e+00],
#        [2.22377778e+00, 2.22377778e+00, 2.22377778e+00, 2.22377778e+00,
#         2.22377778e+00, 2.22377778e+00, 2.22377778e+00, 2.22377778e+00,
